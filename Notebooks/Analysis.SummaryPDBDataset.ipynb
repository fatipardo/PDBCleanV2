# %%
from Bio.PDB.MMCIF2Dict import MMCIF2Dict
from PDBClean import pdbclean_io, pdbutils
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Summary of PDB dataset
#
# ## What is the goal of this notebook?
#
#
# This notebook creates a summary of the basic features of a structure dataset. It takes as input the 'raw_bank' directory created during step 0. Users need to create a 'pdblist.txt' with the list of CIFs that will be included in the summary. Users also need to specify the directories where the CIFs are stored, and the directory where the created files will be stored.
#
# In the first step, a pandas dataframe is populated with the info read from the CIFs. The info in the dataframe is then written as a csv file. Additionally, two options are printed for the user asking if they prefer to see the shortened or full name version of the organisms.
# The shortened version only displays the first two words of the organism's name.
#
# (Example - [Full name: 'Leptospira interrogans serovar Icterohaemorrhagiae str. RGA']  --- [Short name: 'Leptospira interrogans'])
#
# In a second step, we create an image with the plots summarizing the data in the dataframe. Four plots are included, a boxplot of the resolution of the structures, a histogram of the year in which the structures were published, a histogram of the methods used to solve the structures, and a histogram of the organism of origin of the molecule in the structure. The image with the four plots is saved as a pdf.
#
# ## How to create the 'pdblist.txt'
#
# This notebook uses 'pdblist.txt' which is derived from the files in the 'raw_bank'. To create the 'pdblist.txt' run this line within the terminal **in the 'raw_bank' directory**:
#
# >ls | grep cif > pdblist.txt

# %% [markdown]
# ## Define functions

# %%
def make_pdb_df(read_directory_path, cif_list):
    """ 
        Extracts information from PDB cif files and creates a DataFrame with it.

        This function reads a list of CIF file names from 'pdblist.txt', extracts relevant information from 
        each CIF file, and compiles this information into a pandas DataFrame. The DataFrame includes details 
        such as PDB IDs, organism names, resolution, publication year, and experimental method. The function 
        also provides an option for users to choose between shortened or full names for the organisms.

        Parameters
        ----------
        read_directory_path : (str)
            The directory path where the CIF files are located and where the output CSV will be saved.
        cif_list : (str) 
            The name of the text file (e.g., 'pdblist.txt') containing the list of CIF file names.

        Returns
        ----------
        pandas.DataFrame  
            A DataFrame with the following columns
            - 'pdb_ids' : The 4 character PDB ID
            - 'orgalist' : Name of organism(s) in the PDB entry, formatted to the user's choice. 
            - 'resolution' : Resolution of structure in angstrom, 0 if not found.
            - 'year': Year of publication of PDB entry, None if not found .
            - 'method' : Experimental method used to determine structure listed in PDB entry, or an empty string if not found.  
    """

    pdb_ids = []
    orgalist = []
    resolution = []
    year = []
    method = []

    cif_name = open(read_directory_path + cif_list,'r')
    cif_name = cif_name.readlines()

    option = int(input('''Select choice:
    For shortened organism name type [1], for full organism type [2] '''))
    
    for item in range(0,len(cif_name)):
        pdb_id = cif_name[item].strip()
        pdb_id = pdb_id[0:4]
        pdb_ids.append(pdb_id)

        #pdbutils.download_pdb_from_id(oldfile, download_dir=read_dir)

        mmcif_dict = MMCIF2Dict(read_directory_path + pdb_id + ".cif")

        
        # Finding the organism
        org_keys = ['_entity_src_nat.pdbx_organism_scientific','_entity_src_gen.pdbx_gene_src_scientific_name',
                      '_em_entity_assembly_naturalsource.organism']
        
        if option == 1:
            org_found = False

            for org in org_keys:
                if org in mmcif_dict:
                    unique_organism = list(set(mmcif_dict[org]))
                    formatted_organisms = set()
                    for organism in unique_organism:
                        parts = organism.split()
                        if len(parts) > 2:
                            formatted_organisms.add(' '.join(parts[:2]).upper())
                        else:
                            formatted_organisms.add(' '.join(parts).upper())
                    
                    formatted_organisms = list(formatted_organisms)# Convert to list if needed
                    orgalist.append('; '.join(formatted_organisms))
                    org_found = True
                    break            

            if not org_found:
                orgalist.append('')
        
        if option == 2:
            org_found = False
            for org in org_keys:
                if org in mmcif_dict:
                    unique_organism = list(set(mmcif_dict[org]))
                    formatted_organisms = []
                    for organism in unique_organism:
                        parts = organism.split()
                        if len(parts) > 2:
                            formatted_organisms.append(' '.join(parts[:len(org)-1]).upper())
                        else:
                            formatted_organisms.append(' '.join(parts).upper())
                
                    orgalist.append('; '.join(formatted_organisms))
                    org_found = True
                    break
                    
            if not org_found:
                orgalist.append('')



        
        #Finding the resolution
        res_keys = ['_refine.ls_d_res_high','_reflns.d_resolution_high', '_em_3d_reconstruction.resolution', '_reflns.d_resolution_high'
                     '_em_3d_reconstruction.resolution', '_reflns.d_resolution_high']
        for res in res_keys:
            if res in mmcif_dict and ((mmcif_dict[res][0] != '?') and (mmcif_dict[res][0] != '.')):
                  resolution.append(float(mmcif_dict[res][0]))
                  break
        else:
            resolution.append(0) 
            

        #Finding the year of publication
        pub_keys = ['_pdbx_database_status.recvd_initial_deposition_date', '_citation.year']
        pub_found = False
        for pub in pub_keys:
            if pub in mmcif_dict and ((mmcif_dict[pub][0][0:4] != '?') and (mmcif_dict[pub][0][0:4] != '.')):
                year.append(int(mmcif_dict[pub][0][0:4])) 
            pub_found = True
            break
       
        if not pub_found:
            year.append(None)  

        
        #Finding the method
        if '_exptl.method' in mmcif_dict:
            method.append(mmcif_dict['_exptl.method'][0])
        else:
            method.append('')
            
            
        print(pdb_ids[item], orgalist[item], resolution[item], year[item],method[item])
        ##print(pdb_ids[item],year[item])


    df = pd.DataFrame(list(zip(pdb_ids, orgalist,resolution,year,method)), 
                      columns = ['PDBid', 'Organism', 'Resolution (Å)','Year','Method'])
    

    
    return(df)
    
    #print(oldfile, orgalist)

# %%
def summary_plots_pdbs(df, output_directory, output_name):
    """
     Generates and saves a collection of summary plots based on the provided DataFrame.

     Parameters
     ----------
     df : (pandas.DataFrame)
         Dataframe containing summarized information on the PDB dataset
     output_directory : (str)
         The directory path where the generated PDF file with the plots will be saved.
     output_name : (str)
         The name of the project directory which is then used to name the output PDF file.

     Returns
     ----------
     None  
         This function saves the plots as a PDF file in the specified output directory and does not return any values.  
    """
    f = plt.figure(figsize = (32, 48))
    gs = f.add_gridspec(2, 2)
    fs = 40

    #PLOT RESOLUTION
    ax = f.add_subplot(gs[0, 0])
    #sns.boxplot(df['Resolution']).set(title="Resolution (Å)")
    #sns.boxplot(df[df['Resolution'].str.match('N/A')==False]['Resolution'])#.set(title="Resolution (Å)")
    sns.histplot(df['Resolution (Å)']) #.set(title="Resolution (Å)")
    plt.yticks(fontsize = fs)
    plt.xticks(fontsize = fs)
    #plt.title('Resolution (Å)', fontsize=fs)
    ax.xaxis.label.set_size(fs)
    ax.yaxis.label.set_size(fs)
    
    
    #PLOT YEAR
    ax = f.add_subplot(gs[0, 1])
    sort_df = df.sort_values(by = "Year", ascending = True)
    plot = sns.histplot(sort_df['Year'])#.set(title="Year of Publication")
    xtick_loc = plot.get_xticks()
    xtick_labels = plot.get_xticklabels()

        # Set the x-axis ticks

    plt.setp(xtick_labels, rotation = 30, ha = "right")#, fontsize = 'x-small')
    plt.yticks(fontsize = fs)
    plt.xticks(fontsize = fs)
    ax.xaxis.label.set_size(fs)
    ax.yaxis.label.set_size(fs)
    
    #PLOT METHOD
    ax = f.add_subplot(gs[1, 0])
    method_counts = df['Method'].value_counts()

    # Only one unique method
    if len(method_counts) == 1:
        
        plot = sns.barplot(x = method_counts.index, y = method_counts.values, ax=ax)
        plt.xticks(rotation = 0, ha = 'center')
        # Font size customize
        plt.yticks(fontsize = fs)
        plt.xticks(fontsize = fs - 10)  # Adjusted font size for x-axis ticks
        ax.xaxis.label.set_size(fs)
        ax.yaxis.label.set_size(fs)
   
    # Multiple methods
    else:
        plot = sns.histplot(df['Method'])
        xtick_loc = plot.get_xticks()
        xtick_labels = plot.get_xticklabels()
        plt.setp(xtick_labels, rotation=30, ha="right")
        # Font size customize
        plt.yticks(fontsize = fs)
        plt.xticks(fontsize = fs - 20)
        ax.xaxis.label.set_size(fs)
        ax.yaxis.label.set_size(fs)

    #PLOT ORGANISM
    ax = f.add_subplot(gs[1, 1])
    sort_df = df['Organism'].value_counts(ascending = False).rename_axis('Organism').rename('count')
    plot = sns.barplot(x = sort_df.index, y = sort_df.values, order = sort_df.index)

        # Get x-axis tick locations and labels

    xtick_loc = plot.get_xticks()
    xtick_labels = plot.get_xticklabels()

        # Set the x-axis ticks

    plt.setp(xtick_labels, rotation = 30, ha = "right", fontsize = 'x-small')
    
    
    plt.subplots_adjust(bottom = 0.4)
    plt.yticks(fontsize = fs)
    ax.xaxis.label.set_size(fs)
    ax.yaxis.label.set_size(fs)


    #print("x-axis tick locations: " + str(xtick_loc))


    plt.savefig(output_directory + '/' + output_name + "_summary_plots.pdf")

# %% [markdown]
# ## Specify working directories

# %%
# TIM
PROJDIR = './TIM/'
read_directory_path = PROJDIR + '/raw_bank/'
cif_list = 'pdblist.txt'
output_directory = PROJDIR + '/SUMMARY/'
org_name = 'TIM'

# %%
pdbclean_io.check_project(projdir = PROJDIR, level = 'SUMMARY')

# %% [markdown]
# ## Run functions
#
# 1. Populate dataframe with basic info of each structure: 'PDBid', 'Organism', 'Resolution','Year', 'Method'
# 2. Create plots with summary of the basic info.

# %%
# Populate dataframe
# Funcion prints items to screen
df = make_pdb_df(read_directory_path, cif_list)
# Out:
# Select choice:
#     For shortened organism name type [1], for full organism type [2] 1
# 1ag1 TRYPANOSOMA BRUCEI 2.36 1997 X-RAY DIFFRACTION
# 1aw1 MORITELLA MARINA 2.7 1997 X-RAY DIFFRACTION
# 1aw2 MORITELLA MARINA 2.65 1997 X-RAY DIFFRACTION
# 1b9b THERMOTOGA MARITIMA 2.85 1999 X-RAY DIFFRACTION
# 1btm GEOBACILLUS STEAROTHERMOPHILUS 2.8 1995 X-RAY DIFFRACTION
# 1ci1 TRYPANOSOMA CRUZI 2.0 1999 X-RAY DIFFRACTION
# 1dkw TRYPANOSOMA BRUCEI 2.65 1999 X-RAY DIFFRACTION
# 1hg3 PYROCOCCUS WOESEI 2.7 2000 X-RAY DIFFRACTION
# 1hti HOMO SAPIENS 2.8 1994 X-RAY DIFFRACTION
# 1i45 SACCHAROMYCES CEREVISIAE 1.8 2001 X-RAY DIFFRACTION
# 1if2 LEISHMANIA MEXICANA 2.0 2001 X-RAY DIFFRACTION
# 1iig TRYPANOSOMA BRUCEI 2.6 2001 X-RAY DIFFRACTION
# 1iih TRYPANOSOMA BRUCEI 2.2 2001 X-RAY DIFFRACTION
# 1klg HOMO SAPIENS; STAPHYLOCOCCUS AUREUS 2.4 2001 X-RAY DIFFRACTION
# 1klu HOMO SAPIENS; STAPHYLOCOCCUS AUREUS 1.93 2001 X-RAY DIFFRACTION
# 1kv5 TRYPANOSOMA BRUCEI 1.65 2002 X-RAY DIFFRACTION
# 1lyx PLASMODIUM FALCIPARUM 1.9 2002 X-RAY DIFFRACTION
# 1lzo PLASMODIUM FALCIPARUM 2.8 2002 X-RAY DIFFRACTION
# 1m6j ENTAMOEBA HISTOLYTICA 1.5 2002 X-RAY DIFFRACTION
# 1m7o PLASMODIUM FALCIPARUM 2.4 2002 X-RAY DIFFRACTION
# 1m7p PLASMODIUM FALCIPARUM 2.4 2002 X-RAY DIFFRACTION
# 1ml1 TRYPANOSOMA BRUCEI 2.6 1996 X-RAY DIFFRACTION
# 1mo0 CAENORHABDITIS ELEGANS 1.7 2002 X-RAY DIFFRACTION
# 1mss TRYPANOSOMA BRUCEI 2.4 1994 X-RAY DIFFRACTION
# 1n55 LEISHMANIA MEXICANA 0.83 2002 X-RAY DIFFRACTION
# 1ney SACCHAROMYCES CEREVISIAE 1.2 2002 X-RAY DIFFRACTION
# 1nf0 SACCHAROMYCES CEREVISIAE 1.6 2002 X-RAY DIFFRACTION
# 1o5x PLASMODIUM FALCIPARUM 1.1 2003 X-RAY DIFFRACTION
# 1qds LEISHMANIA MEXICANA 2.0 1999 X-RAY DIFFRACTION
# 1r2r ORYCTOLAGUS CUNICULUS 1.5 2003 X-RAY DIFFRACTION
# 1r2s ORYCTOLAGUS CUNICULUS 2.85 2003 X-RAY DIFFRACTION
# 1r2t ORYCTOLAGUS CUNICULUS 2.25 2003 X-RAY DIFFRACTION
# 1spq GALLUS GALLUS 2.16 2004 X-RAY DIFFRACTION
# 1sq7 GALLUS GALLUS 2.85 2004 X-RAY DIFFRACTION
# 1ssd GALLUS GALLUS 2.9 2004 X-RAY DIFFRACTION
# 1ssg GALLUS GALLUS 2.9 2004 X-RAY DIFFRACTION
# 1su5 GALLUS GALLUS 2.7 2004 X-RAY DIFFRACTION
# 1sux TRYPANOSOMA CRUZI 2.0 2004 X-RAY DIFFRACTION
# 1sw0 GALLUS GALLUS 1.71 2004 X-RAY DIFFRACTION
# 1sw3 GALLUS GALLUS 2.03 2004 X-RAY DIFFRACTION
# 1sw7 GALLUS GALLUS 2.22 2004 X-RAY DIFFRACTION
# 1tcd TRYPANOSOMA CRUZI 1.83 1998 X-RAY DIFFRACTION
# 1tim GALLUS GALLUS 2.5 1976 X-RAY DIFFRACTION
# 1tmh ESCHERICHIA COLI 2.8 1994 X-RAY DIFFRACTION
# 1tpb GALLUS GALLUS 1.9 1994 X-RAY DIFFRACTION
# 1tpc GALLUS GALLUS 1.9 1994 X-RAY DIFFRACTION
# 1tpd TRYPANOSOMA BRUCEI 2.1 1994 X-RAY DIFFRACTION
# 1tpe TRYPANOSOMA BRUCEI 2.1 1994 X-RAY DIFFRACTION
# 1tpf TRYPANOSOMA BRUCEI 1.8 1994 X-RAY DIFFRACTION
# 1tph GALLUS GALLUS 1.8 1993 X-RAY DIFFRACTION
# 1tpu GALLUS GALLUS 1.9 1994 X-RAY DIFFRACTION
# 1tpv GALLUS GALLUS 1.9 1994 X-RAY DIFFRACTION
# 1tpw GALLUS GALLUS 1.9 1994 X-RAY DIFFRACTION
# 1trd TRYPANOSOMA BRUCEI 2.5 1992 X-RAY DIFFRACTION
# 1tre ESCHERICHIA COLI 2.6 1992 X-RAY DIFFRACTION
# 1tri TRYPANOSOMA BRUCEI 2.4 1993 X-RAY DIFFRACTION
# 1tsi TRYPANOSOMA BRUCEI 2.84 1992 X-RAY DIFFRACTION
# 1tti TRYPANOSOMA BRUCEI 2.4 1995 X-RAY DIFFRACTION
# 1ttj TRYPANOSOMA BRUCEI 2.4 1995 X-RAY DIFFRACTION
# 1vga PLASMODIUM FALCIPARUM 1.8 2004 X-RAY DIFFRACTION
# 1w0m THERMOPROTEUS TENAX 2.5 2004 X-RAY DIFFRACTION
# 1woa PLASMODIUM FALCIPARUM 2.8 2004 X-RAY DIFFRACTION
# 1wob PLASMODIUM FALCIPARUM 2.8 2004 X-RAY DIFFRACTION
# 1wyi HOMO SAPIENS 2.2 2005 X-RAY DIFFRACTION
# 1ydv PLASMODIUM FALCIPARUM 2.2 1997 X-RAY DIFFRACTION
# 1ypi SACCHAROMYCES CEREVISIAE 1.9 1990 X-RAY DIFFRACTION
# 1yya THERMUS THERMOPHILUS 1.6 2005 X-RAY DIFFRACTION
# 2btm GEOBACILLUS STEAROTHERMOPHILUS 2.4 1999 X-RAY DIFFRACTION
# 2dp3 GIARDIA INTESTINALIS 2.1 2006 X-RAY DIFFRACTION
# 2h6r METHANOCALDOCOCCUS JANNASCHII 2.3 2006 X-RAY DIFFRACTION
# 2i9e TENEBRIO MOLITOR 2.0 2006 X-RAY DIFFRACTION
# 2iam HOMO SAPIENS 2.8 2006 X-RAY DIFFRACTION
# 2ian HOMO SAPIENS 2.8 2006 X-RAY DIFFRACTION
# 2j24 TRYPANOSOMA BRUCEI 2.1 2006 X-RAY DIFFRACTION
# 2j27 TRYPANOSOMA BRUCEI 1.15 2006 X-RAY DIFFRACTION
# 2jgq HELICOBACTER PYLORI 2.3 2007 X-RAY DIFFRACTION
# 2jk2 HOMO SAPIENS 1.7 2008 X-RAY DIFFRACTION
# 2oma TRYPANOSOMA CRUZI 2.15 2007 X-RAY DIFFRACTION
# 2v0t TRYPANOSOMA BRUCEI 2.2 2007 X-RAY DIFFRACTION
# 2v2c TRYPANOSOMA BRUCEI 1.89 2007 X-RAY DIFFRACTION
# 2v2d TRYPANOSOMA BRUCEI 2.3 2007 X-RAY DIFFRACTION
# 2v2h TRYPANOSOMA BRUCEI 1.18 2007 X-RAY DIFFRACTION
# 2v5b TRYPANOSOMA CRUZI 2.0 2008 X-RAY DIFFRACTION
# 2v5l TRYPANOSOMA BRUCEI 2.4 2007 X-RAY DIFFRACTION
# 2vei TRYPANOSOMA BRUCEI 1.89 2007 X-RAY DIFFRACTION
# 2vek TRYPANOSOMA BRUCEI 1.6 2007 X-RAY DIFFRACTION
# 2vel TRYPANOSOMA BRUCEI 2.3 2007 X-RAY DIFFRACTION
# 2vem TRYPANOSOMA BRUCEI 2.2 2007 X-RAY DIFFRACTION
# 2ven TRYPANOSOMA BRUCEI 2.0 2007 X-RAY DIFFRACTION
# 2vfd PLASMODIUM FALCIPARUM 1.4 2007 X-RAY DIFFRACTION
# 2vfe PLASMODIUM FALCIPARUM 2.2 2007 X-RAY DIFFRACTION
# 2vff PLASMODIUM FALCIPARUM 1.7 2007 X-RAY DIFFRACTION
# 2vfg PLASMODIUM FALCIPARUM 1.95 2007 X-RAY DIFFRACTION
# 2vfh PLASMODIUM FALCIPARUM 2.0 2007 X-RAY DIFFRACTION
# 2vfi PLASMODIUM FALCIPARUM 2.25 2007 X-RAY DIFFRACTION
# 2vom HOMO SAPIENS 1.85 2008 X-RAY DIFFRACTION
# 2vxn LEISHMANIA MEXICANA 0.82 2008 X-RAY DIFFRACTION
# 2x1r TRYPANOSOMA BRUCEI 1.98 2010 X-RAY DIFFRACTION
# 2x1s TRYPANOSOMA BRUCEI 1.93 2010 X-RAY DIFFRACTION
# 2x1t TRYPANOSOMA BRUCEI 1.83 2010 X-RAY DIFFRACTION
# 2x1u TRYPANOSOMA BRUCEI 1.84 2010 X-RAY DIFFRACTION
# 2x2g TRYPANOSOMA BRUCEI 1.9 2010 X-RAY DIFFRACTION
# 2x16 TRYPANOSOMA BRUCEI 2.13 2009 X-RAY DIFFRACTION
# 2y61 LEISHMANIA MEXICANA 0.99 2011 X-RAY DIFFRACTION
# 2y62 LEISHMANIA MEXICANA 1.08 2011 X-RAY DIFFRACTION
# 2y63 LEISHMANIA MEXICANA 1.97 2011 X-RAY DIFFRACTION
# 2ypi SACCHAROMYCES CEREVISIAE 2.5 1990 X-RAY DIFFRACTION
# 3gvg MYCOBACTERIUM TUBERCULOSIS 1.55 2009 X-RAY DIFFRACTION
# 3krs CRYPTOSPORIDIUM PARVUM 1.55 2009 X-RAY DIFFRACTION
# 3kxq BARTONELLA HENSELAE 1.6 2009 X-RAY DIFFRACTION
# 3m9y STAPHYLOCOCCUS AUREUS 1.9 2010 X-RAY DIFFRACTION
# 3pf3 GIARDIA INTESTINALIS 2.098 2010 X-RAY DIFFRACTION
# 3psv PLASMODIUM FALCIPARUM 2.0 2010 X-RAY DIFFRACTION
# 3psw PLASMODIUM FALCIPARUM 1.99 2010 X-RAY DIFFRACTION
# 3pvf PLASMODIUM FALCIPARUM 1.73 2010 X-RAY DIFFRACTION
# 3pwa PLASMODIUM FALCIPARUM 2.04 2010 X-RAY DIFFRACTION
# 3py2 PLASMODIUM FALCIPARUM 1.93 2010 X-RAY DIFFRACTION
# 3qsr TRICHOMONAS VAGINALIS 2.05 2011 X-RAY DIFFRACTION
# 3qst TRICHOMONAS VAGINALIS 1.75 2011 X-RAY DIFFRACTION
# 3s6d COCCIDIOIDES IMMITIS 2.2 2011 X-RAY DIFFRACTION
# 3ta6 MYCOBACTERIUM TUBERCULOSIS 1.41 2011 X-RAY DIFFRACTION
# 3tao MYCOBACTERIUM TUBERCULOSIS 1.45 2011 X-RAY DIFFRACTION
# 3th6 RHIPICEPHALUS MICROPLUS 2.4 2011 X-RAY DIFFRACTION
# 3tim TRYPANOSOMA BRUCEI 2.8 1990 X-RAY DIFFRACTION
# 3uwu STAPHYLOCOCCUS AUREUS 2.15 2011 X-RAY DIFFRACTION
# 3uwv STAPHYLOCOCCUS AUREUS 2.07 2011 X-RAY DIFFRACTION
# 3uww STAPHYLOCOCCUS AUREUS 2.25 2011 X-RAY DIFFRACTION
# 3uwy STAPHYLOCOCCUS AUREUS 2.4 2011 X-RAY DIFFRACTION
# 3uwz STAPHYLOCOCCUS AUREUS 2.5 2011 X-RAY DIFFRACTION
# 3ypi SACCHAROMYCES CEREVISIAE 2.8 1990 X-RAY DIFFRACTION
# 4bi5 GIARDIA INTESTINALIS 2.7 2013 X-RAY DIFFRACTION
# 4bi6 GIARDIA INTESTINALIS 1.45 2013 X-RAY DIFFRACTION
# 4bi7 GIARDIA INTESTINALIS 1.6 2013 X-RAY DIFFRACTION
# 4br1 HOMO SAPIENS 1.9 2013 X-RAY DIFFRACTION
# 4e41 HOMO SAPIENS 2.6 2012 X-RAY DIFFRACTION
# 4ff7 SACCHAROMYCES CEREVISIAE 1.86 2012 X-RAY DIFFRACTION
# 4g1k BURKHOLDERIA THAILANDENSIS 2.35 2012 X-RAY DIFFRACTION
# 4gnj LEISHMANIA SP. 1.93 2012 X-RAY DIFFRACTION
# 4hhp TRYPANOSOMA CRUZI 1.5 2012 X-RAY DIFFRACTION
# 4iot ESCHERICHIA COLI 1.85 2013 X-RAY DIFFRACTION
# 4jeq TRYPANOSOMA CRUZI 2.303 2013 X-RAY DIFFRACTION
# 4k6a ESCHERICHIA COLI 1.8 2013 X-RAY DIFFRACTION
# 4mkn CHLAMYDOMONAS REINHARDTII 1.1 2013 X-RAY DIFFRACTION
# 4mva ESCHERICHIA COLI 1.43 2013 X-RAY DIFFRACTION
# 4nvt BRUCELLA MELITENSIS 2.1 2013 X-RAY DIFFRACTION
# 4o4v TRICHOMONAS VAGINALIS 1.23 2013 X-RAY DIFFRACTION
# 4o4w TRICHOMONAS VAGINALIS 2.35 2013 X-RAY DIFFRACTION
# 4o50 TRICHOMONAS VAGINALIS 1.95 2013 X-RAY DIFFRACTION
# 4o52 TRICHOMONAS VAGINALIS 1.95 2013 X-RAY DIFFRACTION
# 4o53 TRICHOMONAS VAGINALIS 2.0 2013 X-RAY DIFFRACTION
# 4o54 TRICHOMONAS VAGINALIS 1.9 2013 X-RAY DIFFRACTION
# 4o57 TRICHOMONAS VAGINALIS 1.793 2013 X-RAY DIFFRACTION
# 4obt ARABIDOPSIS THALIANA 1.6 2014 X-RAY DIFFRACTION
# 4ohq ARABIDOPSIS THALIANA 2.15 2014 X-RAY DIFFRACTION
# 4owg ORYCTOLAGUS CUNICULUS 1.55 2014 X-RAY DIFFRACTION
# 4p61 GALLUS GALLUS 1.34 2014 X-RAY DIFFRACTION
# 4poc HOMO SAPIENS 1.601 2014 X-RAY DIFFRACTION
# 4pod HOMO SAPIENS 1.99 2014 X-RAY DIFFRACTION
# 4rcx TRICHOMONAS VAGINALIS 1.75 2014 X-RAY DIFFRACTION
# 4tim TRYPANOSOMA BRUCEI 2.4 1991 X-RAY DIFFRACTION
# 4unk HOMO SAPIENS 2.0 2014 X-RAY DIFFRACTION
# 4unl HOMO SAPIENS 1.5 2014 X-RAY DIFFRACTION
# 4wje TRICHOMONAS VAGINALIS 1.285 2014 X-RAY DIFFRACTION
# 4x22 LEPTOSPIRA INTERROGANS 2.084 2014 X-RAY DIFFRACTION
# 4y8f CLOSTRIDIUM PERFRINGENS 1.54 2015 X-RAY DIFFRACTION
# 4y9a STREPTOMYCES COELICOLOR 2.294 2015 X-RAY DIFFRACTION
# 4y90 DEINOCOCCUS RADIODURANS 2.1 2015 X-RAY DIFFRACTION
# 4y96 GEMMATA OBSCURIGLOBUS 1.581 2015 X-RAY DIFFRACTION
# 4ymz LEPTOSPIRA INTERROGANS 1.87 2015 X-RAY DIFFRACTION
# 4ywi PLASMODIUM FALCIPARUM 1.85 2015 X-RAY DIFFRACTION
# 4yxg PLASMODIUM FALCIPARUM 1.9 2015 X-RAY DIFFRACTION
# 4z0j PLASMODIUM FALCIPARUM 2.07 2015 X-RAY DIFFRACTION
# 4z0s PLASMODIUM FALCIPARUM 2.39 2015 X-RAY DIFFRACTION
# 4zvj HOMO SAPIENS 1.6996 2015 X-RAY DIFFRACTION
# 4zz9 PLASMODIUM FALCIPARUM 1.81 2015 X-RAY DIFFRACTION
# 5bmw PLASMODIUM FALCIPARUM 1.86 2015 X-RAY DIFFRACTION
# 5bmx PLASMODIUM FALCIPARUM 1.8 2015 X-RAY DIFFRACTION
# 5bnk PLASMODIUM FALCIPARUM 1.8 2015 X-RAY DIFFRACTION
# 5brb PLASMODIUM FALCIPARUM 2.53 2015 X-RAY DIFFRACTION
# 5csr THERMOPLASMA ACIDOPHILUM 1.94 2015 X-RAY DIFFRACTION
# 5css THERMOPLASMA ACIDOPHILUM 2.17 2015 X-RAY DIFFRACTION
# 5eyw LITOPENAEUS VANNAMEI 1.7 2015 X-RAY DIFFRACTION
# 5gv4 PLASMODIUM FALCIPARUM 2.09 2016 X-RAY DIFFRACTION
# 5gzp PLASMODIUM FALCIPARUM 2.03 2016 X-RAY DIFFRACTION
# 5i3f TRYPANOSOMA BRUCEI 1.72 2016 X-RAY DIFFRACTION
# 5i3g TRYPANOSOMA BRUCEI 1.96 2016 X-RAY DIFFRACTION
# 5i3h TRYPANOSOMA BRUCEI 2.25 2016 X-RAY DIFFRACTION
# 5i3i TRYPANOSOMA BRUCEI 2.2 2016 X-RAY DIFFRACTION
# 5i3j TRYPANOSOMA BRUCEI 1.8 2016 X-RAY DIFFRACTION
# 5i3k TRYPANOSOMA BRUCEI 2.209 2016 X-RAY DIFFRACTION
# 5ibx STREPTOCOCCUS PNEUMONIAE 1.65 2016 X-RAY DIFFRACTION
# 5tim TRYPANOSOMA BRUCEI 1.83 1991 X-RAY DIFFRACTION
# 5ujw FRANCISELLA TULARENSIS 2.65 2017 X-RAY DIFFRACTION
# 5upr TOXOPLASMA GONDII 2.0 2017 X-RAY DIFFRACTION
# 5vwn TRICHOMONAS VAGINALIS 1.74 2017 X-RAY DIFFRACTION
# 5zfx OPISTHORCHIS VIVERRINI 1.751 2018 X-RAY DIFFRACTION
# 5zg4 OPISTHORCHIS VIVERRINI 1.746 2018 X-RAY DIFFRACTION
# 5zg5 OPISTHORCHIS VIVERRINI 1.597 2018 X-RAY DIFFRACTION
# 5zga OPISTHORCHIS VIVERRINI 1.793 2018 X-RAY DIFFRACTION
# 6bve SYNECHOCYSTIS SP. 1.78 2017 X-RAY DIFFRACTION
# 6c2g HOMO SAPIENS 2.3 2018 X-RAY DIFFRACTION
# 6cg9 ZEA MAYS 1.8 2018 X-RAY DIFFRACTION
# 6d43 HOMO SAPIENS 2.04 2018 X-RAY DIFFRACTION
# 6jox SCYLLA PARAMAMOSAIN 1.803 2019 X-RAY DIFFRACTION
# 6nee SYNTHETIC CONSTRUCT 1.9 2018 X-RAY DIFFRACTION
# 6nlh HOMO SAPIENS 2.199 2019 X-RAY DIFFRACTION
# 6nxq ARABIDOPSIS THALIANA 1.96 2019 X-RAY DIFFRACTION
# 6nxr ARABIDOPSIS THALIANA 1.3 2019 X-RAY DIFFRACTION
# 6nxs ARABIDOPSIS THALIANA 1.52 2019 X-RAY DIFFRACTION
# 6nxw ARABIDOPSIS THALIANA 1.95 2019 X-RAY DIFFRACTION
# 6nxx ARABIDOPSIS THALIANA 1.64 2019 X-RAY DIFFRACTION
# 6nxy ARABIDOPSIS THALIANA 1.05 2019 X-RAY DIFFRACTION
# 6oog TAENIA SOLIUM 2.02 2019 X-RAY DIFFRACTION
# 6ooi SCHISTOSOMA MANSONI 2.14 2019 X-RAY DIFFRACTION
# 6r8h FASCIOLA HEPATICA 1.9 2019 X-RAY DIFFRACTION
# 6tim TRYPANOSOMA BRUCEI 2.2 1991 X-RAY DIFFRACTION
# 6up1 HOMO SAPIENS 1.83 2019 X-RAY DIFFRACTION
# 6up5 HOMO SAPIENS 1.92 2019 X-RAY DIFFRACTION
# 6up8 HOMO SAPIENS 2.0 2019 X-RAY DIFFRACTION
# 6upf HOMO SAPIENS 1.65 2019 X-RAY DIFFRACTION
# 6w4u STENOTROPHOMONAS MALTOPHILIA 1.7 2020 X-RAY DIFFRACTION
# 7abx LEISHMANIA MEXICANA 1.2 2020 X-RAY DIFFRACTION
# 7az3 LEISHMANIA MEXICANA 1.15 2020 X-RAY DIFFRACTION
# 7az4 LEISHMANIA MEXICANA 1.15 2020 X-RAY DIFFRACTION
# 7az9 LEISHMANIA MEXICANA 1.1 2020 X-RAY DIFFRACTION
# 7aza LEISHMANIA MEXICANA 1.1 2020 X-RAY DIFFRACTION
# 7n8u CANDIDATUS PROMETHEOARCHAEUM 1.98 2021 X-RAY DIFFRACTION
# 7pej SCHIZOSACCHAROMYCES POMBE 1.79 2021 X-RAY DIFFRACTION
# 7pek SCHIZOSACCHAROMYCES POMBE 1.74 2021 X-RAY DIFFRACTION
# 7qh0 LEISHMANIA MEXICANA 2.15 2021 X-RAY DIFFRACTION
# 7qon FASCIOLA HEPATICA 1.51 2021 X-RAY DIFFRACTION
# 7r7m CANDIDATE DIVISION 2.0 2021 X-RAY DIFFRACTION
# 7r9b CANDIDATUS ROIZMANBACTERIA 2.2 2021 X-RAY DIFFRACTION
# 7rcq KTEDONOBACTER RACEMIFER 1.7 2021 X-RAY DIFFRACTION
# 7rde HOMO SAPIENS 1.31 2021 X-RAY DIFFRACTION
# 7rgc CANDIDATE DIVISION 2.09 2021 X-RAY DIFFRACTION
# 7rmn VERRUCOMICROBIUM SPINOSUM 1.21 2021 X-RAY DIFFRACTION
# 7rpn BACTEROIDES THETAIOTAOMICRON 1.37 2021 X-RAY DIFFRACTION
# 7skj CUSCUTA AUSTRALIS 1.9 2021 X-RAY DIFFRACTION
# 7sx1 HOMO SAPIENS 2.23 2021 X-RAY DIFFRACTION
# 7t0q HOMO SAPIENS 2.0 2021 X-RAY DIFFRACTION
# 7tim SACCHAROMYCES CEREVISIAE 1.9 1991 X-RAY DIFFRACTION
# 7uxb HOMO SAPIENS 2.0 2022 X-RAY DIFFRACTION
# 7uxv HOMO SAPIENS 2.15 2022 X-RAY DIFFRACTION
# 7v03 CUSCUTA AUSTRALIS 1.78 2022 X-RAY DIFFRACTION
# 8j7c LEISHMANIA ORIENTALIS 1.88 2023 X-RAY DIFFRACTION
# 8jbp LEISHMANIA ORIENTALIS 1.45 2023 X-RAY DIFFRACTION
# 8tim GALLUS GALLUS 2.5 1998 X-RAY DIFFRACTION
# 8uz7 PENAEUS VANNAMEI 1.7 2023 X-RAY DIFFRACTION
# 8v0a SYNTHETIC CONSTRUCT 2.05 2023 X-RAY DIFFRACTION
# 8v09 SYNTHETIC CONSTRUCT 1.61 2023 X-RAY DIFFRACTION
# 8v2w SYNTHETIC CONSTRUCT 1.38 2023 X-RAY DIFFRACTION
# 8v2x SYNTHETIC CONSTRUCT 1.43 2023 X-RAY DIFFRACTION
# 8w05 SYNTHETIC CONSTRUCT 2.16 2024 X-RAY DIFFRACTION
# 8w06 SYNTHETIC CONSTRUCT 2.06 2024 X-RAY DIFFRACTION
# 8w08 SYNTHETIC CONSTRUCT 1.88 2024 X-RAY DIFFRACTION
# 9f69 HOMO SAPIENS 1.17 2024 X-RAY DIFFRACTION
# 9ffc HOMO SAPIENS 1.25 2024 X-RAY DIFFRACTION
# 9qus RHODONELLUM PSYCHROPHILUM 1.5 2025 X-RAY DIFFRACTION
# 9quu RHODOCOCCUS SP. 1.63 2025 X-RAY DIFFRACTION

# %%
# Write dataframe as CSV file 

df.to_csv(output_directory + org_name + '.csv')

# %%
# Create images with the plots summarizing the info in the dataframe

summary_plots_pdbs(df, output_directory, org_name)
